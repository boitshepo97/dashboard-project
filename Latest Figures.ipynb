# %%
import pandas as pd
import numpy as np

# %%
def load_data():
    latest_figures = pd.read_csv("Data_ ReliefWeb Crisis Figures Data - latest_figures.csv")
    latest_figures .columns = ['crisis_index','crisis_name','crisis_iso3','figure_name',
                               'figure_date','figure_value','figure_source','figure_url']
    return(latest_figures)

# %%
crisis = pd.read_csv("Data_ ReliefWeb Crisis Figures Data - latest_figures.csv")

# %%
crisis.head(100)
# Out:
#     crisis_index               crisis_name crisis_iso3  \
# 0              0               Afghanistan         AFG
# 1              0               Afghanistan         AFG
# 2              0               Afghanistan         AFG
# 3              0               Afghanistan         AFG
# 4              0               Afghanistan         AFG
# ..           ...                       ...         ...
# 95             5  Central African Republic         CAF
# 96             5  Central African Republic         CAF
# 97             5  Central African Republic         CAF
# 98             5  Central African Republic         CAF
# 99             5  Central African Republic         CAF
#
#                                           figure_name figure_source  \
# 0                                      People in Need          OCHA
# 1                      People Targeted for Assistance          OCHA
# 2                                    Children in Need        UNICEF
# 3      People in Food Crisis/Emergency (IPC phase 3+)           IPC
# 4   Undocumented Afghan Returnees from Iran (per y...           IOM
# ..                                                ...           ...
# 95                           CAR Refugees in Cameroon         UNHCR
# 96  CAR Refugees Repatriated from Cameroon (cumula...         UNHCR
# 97              CAR Refugees & Asylum-Seekers in Chad         UNHCR
# 98                                CAR Refugees in DRC         UNHCR
# 99                        CAR Refugees in South Sudan         UNHCR
#
#     figure_value figure_date                              figure_url
# 0        9400000  2019-12-31  https://m.reliefweb.int/report/3460128
# 1        7100000  2019-12-31  https://m.reliefweb.int/report/3460128
# 2        5100000  2019-12-04  https://m.reliefweb.int/report/3425323
# 3       10232000  2019-11-15  https://m.reliefweb.int/report/3396223
# 4          45113  2020-02-15  https://m.reliefweb.int/report/3547223
# ..           ...         ...                                     ...
# 95        293277  2020-01-31  https://data2.unhcr.org/en/country/cmr
# 96          3559  2020-02-26  https://m.reliefweb.int/report/3541203
# 97         94438  2020-02-29      https://reliefweb.int/node/3548773
# 98        171400  2020-01-31      https://reliefweb.int/node/3552653
# 99          2083  2020-01-31  https://m.reliefweb.int/report/3514799
#
# [100 rows x 8 columns]

# %%
crisis.crisis_name
# Out:
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
#           ...
# 587       Zimbabwe
# 588       Zimbabwe
# 589       Zimbabwe
# 590       Zimbabwe
# 591       Zimbabwe
# Name: crisis_name, Length: 592, dtype: object
